# %% [markdown]
# # 4.8 Grouping Data Task Questions

# %%
# Import Libraries

import pandas as pd
import numpy as np
import os

# %%
# Creating Path

path = r"C:\Users\caden\OneDrive\Desktop\Instacart Basket Analysis 06.22.2022"

# %%
# Import Orders_products_merged

df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02. Data', 'Prepared Data', 'orders_products_altered.pkl'))

# %%
df=df_ords_prods_merged

# %% [markdown]
# # Question 2

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# # Question 3

# %%
# The two sets have similar means. There are some variations, which is expected since the first set was smaller, but as a whole they are consistent.

# %% [markdown]
# # Question 4

# %%
# Creating a loyalty flag

df['max_order'] = df.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Check

df.head(100)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# ..       ...      ...      ...           ...                ...
# 95   3226575      360    prior             1                  5
# 96   1469869      377    prior             3                  5
# 97   1927023      387    prior             2                  4
# 98    858092      420    prior             4                  1
# 99    119314      420    prior             5                  3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# ...

# %%
#Creating and assigning the loyalty flag for the new column


df.loc[df['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df.loc[(df['max_order'] <= 40) & (df['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df.loc[df['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Checking frequency

df['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
df.head(100)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# ..       ...      ...      ...           ...                ...
# 95   3226575      360    prior             1                  5
# 96   1469869      377    prior             3                  5
# 97   1927023      387    prior             2                  4
# 98    858092      420    prior             4                  1
# 99    119314      420    prior             5                  3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# ...

# %% [markdown]
# # Question 5

# %%
# Determining prices of products purchased by different loyalty groups

df.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# ##### On average the more loyal the customer, the least they spend per visit, while new customers spends the most

# %% [markdown]
# # Question 6

# %%
# Creating spending flags for each user

df.groupby('user_id').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#            prices
#              mean  min   max
# user_id
# 1        6.367797  1.0  14.0
# 2        7.515897  1.3  14.8
# 3        8.197727  1.3  14.4
# 4        8.205556  1.4  14.6
# 5        9.189189  3.2  14.8
# ...           ...  ...   ...
# 206205   8.909375  1.4  23.8
# 206206   7.646667  1.1  14.8
# 206207   7.313453  1.2  24.7
# 206208   8.366617  1.1  21.6
# 206209   7.058915  1.1  18.8
#
# [206209 rows x 3 columns]

# %%
df['spending'] = df.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df.loc[df['spending'] < 10, 'spending_flag'] = 'Low spender'

# %%
df.loc[df['spending'] >= 10, 'spending_flag'] = 'High spender'

# %%
# Check

df.head(100)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# ..       ...      ...      ...           ...                ...
# 95   3226575      360    prior             1                  5
# 96   1469869      377    prior             3                  5
# 97   1927023      387    prior             2                  4
# 98    858092      420    prior             4                  1
# 99    119314      420    prior             5                  3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# ...

# %% [markdown]
# # Question 7

# %%
# Creating order frequency

df.groupby('user_id').agg({'days_since_prior_order' : ['mean']})
# Out:
#         days_since_prior_order
#                           mean
# user_id
# 1                    20.259259
# 2                    15.967033
# 3                    11.487179
# 4                    15.357143
# 5                    14.500000
# ...                        ...
# 206205               20.666667
# 206206                4.042705
# 206207               14.879397
# 206208                7.442105
# 206209               20.275862
#
# [206209 rows x 1 columns]

# %%
df['order_frequency'] = df.groupby(['user_id'])['days_since_prior_order'].transform(np.max)

# %%
# Creating Flag

df.loc[df['order_frequency'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
df.loc[(df['order_frequency'] > 10) & (df['order_frequency'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
df.loc[df['order_frequency'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
df.head(100)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# ..       ...      ...      ...           ...                ...
# 95   3226575      360    prior             1                  5
# 96   1469869      377    prior             3                  5
# 97   1927023      387    prior             2                  4
# 98    858092      420    prior             4                  1
# 99    119314      420    prior             5                  3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# ...

# %% [markdown]
# # Exporting

# %%
df.to_pickle(os.path.join(path, '02. Data','Prepared Data', 'orders_products_grouped.pkl'))

# %% [markdown]
# # Revised end with additional cleaning code from Ex 4.9

# %%
## Code use to assign Nan values to entries "df.loc[df['prices'] >100, 'prices'] = np.nan"
